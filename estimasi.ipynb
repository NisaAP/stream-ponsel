# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-ac7c60dd-98d7-43ea-9465-78a51cb4ac29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac7c60dd-98d7-43ea-9465-78a51cb4ac29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle
# Out:
# kaggle.json

# %%
# !kaggle datasets download -d mohannapd/mobile-price-prediction
# Out:
# ...
#   0% 0.00/19.3k [00:00<?, ?B/s]
# 100% 19.3k/19.3k [00:00<00:00, 35.4MB/s]

# %%
# !mkdir mobile-price-prediction
# !unzip mobile-price-prediction.zip -d mobile-price-prediction
# !ls mobile-price-prediction
# Out:
# Archive:  mobile-price-prediction.zip
#   inflating: mobile-price-prediction/Cellphone.csv
#   inflating: mobile-price-prediction/Cellphone.xlsx
# Cellphone.csv  Cellphone.xlsx

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mobile-price-prediction/Cellphone.csv')

# %%
df.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
features=['Sale','weight','resoloution','ppi','cpu core','cpu freq','internal mem','ram']
x=df[features]
y=df['Price']
x.shape,y.shape
# Out:
# ((161, 8), (161,))

# %%
x_train,X_test,y_train,y_test= train_test_split(x,y,random_state=70)
y_test.shape
# Out:
# (41,)

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
pred = lr.predict(X_test)

# %%
score =lr.score(X_test, y_test)
print('Akurasi model regresi linier =', score)
# Out:
# Akurasi model regresi linier = 0.9131943079290696

# %%
input_data =np.array([[11,118.5,4.1,232,8,1.35,1.60,3.000]])
prediction =lr.predict(input_data)
print('Estimasi harga handphone :', prediction)
# Out:
# Estimasi harga handphone : [2324.21245766]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename ='estimasi_HP.sav'
pickle.dump(lr,open(filename,'wb'))
